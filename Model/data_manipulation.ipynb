# %%
import pandas as pd
import numpy as np
import re

# %%
house_pricing_data = pd.read_csv('../house_data.csv')

# REMOVING THE EMPTY TITLE ROWS
house_pricing_data.dropna(subset=['title'], inplace=True)
house_pricing_data
# Out:
#        bedroom parking_lot  bathroom toilets    town  state serviced  extras  \
# 0          6.0          No       6.0       7   Ikoyi  Lagos       No     NaN
# 1          3.0          No       3.0       4   Ikoyi  Lagos       No     NaN
# 2          3.0          No       3.0       4   Ikoyi  Lagos       No     NaN
# 3          3.0          No       3.0       4   Ikoyi  Lagos       No     NaN
# 4          3.0          No       3.0       4   Ikoyi  Lagos       No     NaN
# ...        ...         ...       ...     ...     ...    ...      ...     ...
# 12028      1.0         Yes       1.0       1  Oshodi  Lagos       No     8.0
# 12029      5.0          No       6.0       6   Ikoyi  Lagos      Yes     NaN
# 12030      4.0          No       5.0       5   Ikoyi  Lagos       No     NaN
# 12031      2.0          No       2.0       3   Lekki  Lagos       No     NaN
# 12032      2.0          No       2.0       3   Lekki  Lagos       No     NaN
#
#       Stable Electricity                               title  \
# 0                     No                     Detached Duplex
# 1                     No                      Flat Apartment
# 2                     No                      Flat Apartment
# 3                     No                      Flat Apartment
# 4                     No                      Flat Apartment
# ...                  ...                                 ...
# 12028                 No  mini flat Mini Flat Flat Apartment
# 12029                 No                     Terraced Duplex
# 12030                 No                     Terraced Duplex
# 12031                 No                     Blocks Of Flats
# 12032                 No                     Blocks Of Flats
#
#                     price
# 0       ₦250,000,000/year
# 1        ₦40,000,000/year
# 2        ₦20,000,000/year
# 3        ₦20,000,000/year
# 4        ₦20,000,000/year
# ...                   ...
# 12028       ₦800,000/year
# 12029    ₦20,000,000/year
# 12030    ₦40,000,000/year
# 12031     ₦8,500,000/year
# 12032    ₦13,000,000/year
#
# [7855 rows x 11 columns]

# %%
house_pricing_data.loc[
    house_pricing_data["title"].str.lower().str.count(r"mini flat") == 2, "title"
] = "Mini flat Apartment"

# %%
# Fill NaN Values in Extra Column with 0
house_pricing_data["extras"].fillna(value=0, inplace=True)
house_pricing_data.head(40)
# Out:
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/831004178.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_pricing_data["extras"].fillna(value=0, inplace=True)
#     bedroom parking_lot  bathroom toilets             town  state serviced  \
# 0       6.0          No       6.0       7            Ikoyi  Lagos       No
# 1       3.0          No       3.0       4            Ikoyi  Lagos       No
# 2       3.0          No       3.0       4            Ikoyi  Lagos       No
# 3       3.0          No       3.0       4            Ikoyi  Lagos       No
# 4       3.0          No       3.0       4            Ikoyi  Lagos       No
# 5       3.0          No       3.0       4            Ikoyi  Lagos       No
# 6       2.0          No       2.0       3            Ikoyi  Lagos       No
# 7       3.0          No       3.0       4  Victoria Island  Lagos       No
# 8       3.0          No       3.0       4            Ikoyi  Lagos       No
# 9       5.0          No       5.0       6            Ikoyi  Lagos       No
# 10      2.0          No       2.0       3            Ikoyi  Lagos       No
# 11      4.0          No       4.0       5  Victoria Island  Lagos       No
# 12      3.0          No       3.0       4            Ikoyi  Lagos       No
# 13      4.0          No       4.0       5            Ikoyi  Lagos       No
# 14      4.0          No       4.0       5            Ikoyi  Lagos       No
# 15      3.0          No       3.0       4            Ikoyi  Lagos       No
# 16      2.0         Yes       2.0       3            Lekki  Lagos       No
# 17      3.0          No       3.0       4            Ikoyi  Lagos       No
# 18      3.0          No       3.0       4            Ikoyi  Lagos       No
# 19      3.0          No       3.0       4            Ikoyi  Lagos       No
# 20      4.0         Yes       5.0       5            Ikeja  Lagos       No
# 21      1.0          No       1.0       1          Shomolu  Lagos       No
# 23      1.0          No       2.0       2          Ilupeju  Lagos       No
# 25      4.0         Yes       4.0       5            Ikoyi  Lagos       No
# 26      3.0         Yes       3.0       4            Ikoyi  Lagos       No
# 27      2.0         Yes       2.0       3            Ikoyi  Lagos       No
# 28      4.0         Yes       4.0       5            Lekki  Lagos       No
# 29      3.0         Yes       3.0       4            Lekki  Lagos       No
# 30      2.0         Yes       2.0       3            Lekki  Lagos       No
# 32      2.0         Yes       2.0       3            Ikoyi  Lagos       No
# 33      3.0         Yes       3.0       4            Ikoyi  Lagos       No
# 34      2.0         Yes       2.0       3            Lekki  Lagos       No
# 35      2.0         Yes       2.0       3            Lekki  Lagos       No
# 36      2.0         Yes       2.0       3            Lekki  Lagos       No
# 37      2.0         Yes       2.0       3            Lekki  Lagos       No
# 38      3.0         Yes       3.0       4            Lekki  Lagos       No
# 39      4.0         Yes       4.0       5            Ikoyi  Lagos       No
# 40      3.0          No       3.0       4            Lekki  Lagos       No
# 42      4.0          No       5.0       5          Asokoro  Abuja       No
# 43      4.0         Yes       5.0       5           Guzape  Abuja       No
#
#     extras Stable Electricity                                  title  \
# 0      0.0                 No                        Detached Duplex
# 1      0.0                 No                         Flat Apartment
# 2      0.0                 No                         Flat Apartment
# 3      0.0                 No                         Flat Apartment
# 4      0.0                 No                         Flat Apartment
# 5      0.0                 No                         Flat Apartment
# 6      0.0                 No                         Flat Apartment
# 7      0.0                 No                         Flat Apartment
# 8      0.0                 No                         Flat Apartment
# 9      0.0                 No                        Detached Duplex
# 10     0.0                 No                         Flat Apartment
# 11     0.0                 No               Penthouse Flat Apartment
# 12     0.0                 No                         Flat Apartment
# 13     0.0                 No                        Terraced Duplex
# 14     0.0                 No                   Semi Detached Duplex
# 15     0.0                 No                         Flat Apartment
# 16    15.0                Yes                         Flat Apartment
# 17     0.0                 No                         Flat Apartment
# 18     0.0                 No                         Flat Apartment
# 19     0.0                 No                         Flat Apartment
# 20    15.0                 No                        Detached Duplex
# 21     0.0                 No  mini flat Self Contain Flat Apartment
# 23     0.0                 No                    Mini flat Apartment
# 25     8.0                Yes                         Flat Apartment
# 26     8.0                Yes                         Flat Apartment
# 27     8.0                Yes                         Flat Apartment
# 28     8.0                Yes                        Terraced Duplex
# 29     8.0                Yes                         Flat Apartment
# 30     8.0                Yes                         Flat Apartment
# 32     8.0                Yes                         Flat Apartment
# 33     8.0                Yes                         Flat Apartment
# 34     8.0                Yes                         Flat Apartment
# 35     8.0                Yes                         Flat Apartment
# 36     8.0                 No                         Flat Apartment
# 37     8.0                Yes                         Flat Apartment
# 38     8.0                Yes                            Massionette
# 39     8.0                Yes                         Flat Apartment
# 40    11.0                 No                        Terraced Duplex
# 42    18.0                 No                        Detached Duplex
# 43    13.0                 No                        Terraced Duplex
#
#                  price
# 0    ₦250,000,000/year
# 1     ₦40,000,000/year
# 2     ₦20,000,000/year
# 3     ₦20,000,000/year
# 4     ₦20,000,000/year
# 5     ₦39,999,999/year
# 6     ₦34,999,999/year
# 7         $50,000/year
# 8     ₦39,999,999/year
# 9    ₦249,999,999/year
# 10       w Ikoyi Lagos
# 11   ₦178,000,000/year
# 12    ₦30,000,000/year
# 13    ₦29,999,999/year
# 14    ₦29,999,999/year
# 15    ₦75,000,000/year
# 16          ₦8,000,000
# 17         ₦20,000,000
# 18         ₦35,000,000
# 19         ₦15,000,000
# 20         ₦15,000,000
# 21          ₦1,800,000
# 23     ₦1,000,000/year
# 25    ₦60,000,000/year
# 26    ₦25,000,000/year
# 27    ₦20,000,000/year
# 28     ₦6,500,000/year
# 29    ₦13,000,000/year
# 30    ₦10,000,000/year
# 32    ₦66,000,000/year
# 33    ₦84,000,000/year
# 34          ₦8,000,000
# 35         ₦10,000,000
# 36         ₦15,000,000
# 37         ₦10,000,000
# 38    ₦15,000,000/year
# 39    ₦40,000,000/year
# 40          ₦7,500,000
# 42    ₦15,000,000/year
# 43    ₦15,000,000/year

# %%
# Fill the NaN values of the bedrooms, bathrooms and toilet based on the title

house_pricing_data.loc[
    house_pricing_data["title"].str.lower().str.contains("flat apartment") & 
    house_pricing_data["bedroom"].isna(),
    "bedroom"
] = 2

house_pricing_data.loc[
    house_pricing_data["title"].str.lower().str.contains("mini flat") & 
    house_pricing_data["bedroom"].isna(),
    "bedroom"
] = 1

house_pricing_data.loc[
    house_pricing_data["title"].str.lower().str.contains("flat apartment") & 
    house_pricing_data["bathroom"].isna(),
    "bathroom"
] = 1

house_pricing_data.loc[
    house_pricing_data["title"].str.lower().str.contains("flat apartment") & 
    house_pricing_data["toilets"].isna(),
    "toilets"
] = 2
house_pricing_data.isna().sum()
# Out:
# bedroom               183
# parking_lot             0
# bathroom              193
# toilets               184
# town                    0
# state                   0
# serviced                0
# extras                  0
# Stable Electricity      0
# title                   0
# price                   0
# dtype: int64

# %%
house_pricing_data.dropna(inplace=True)
house_pricing_data.shape
# Out:
# (7662, 11)

# %% [markdown]
# ## Price Manipulation

# %%
# WORKING ON PRICE COLUMN
house_pricing_data = house_pricing_data.drop(
     house_pricing_data[
        house_pricing_data["price"].str.contains("/month|/day", na=False)
    ].index
)

# %%
mask = house_pricing_data["price"].str.contains(r"\$", na=False)

house_pricing_data.loc[mask, "price"] = (
    house_pricing_data.loc[mask, "price"]
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)  
    .str.replace('/year', '', regex=False)  
    .astype(float) 
    * 1610  # Convert from USD to NGN
).astype(int)

# %%
house_pricing_data
# Out:
#        bedroom parking_lot  bathroom toilets    town  state serviced  extras  \
# 0          6.0          No       6.0       7   Ikoyi  Lagos       No     0.0
# 1          3.0          No       3.0       4   Ikoyi  Lagos       No     0.0
# 2          3.0          No       3.0       4   Ikoyi  Lagos       No     0.0
# 3          3.0          No       3.0       4   Ikoyi  Lagos       No     0.0
# 4          3.0          No       3.0       4   Ikoyi  Lagos       No     0.0
# ...        ...         ...       ...     ...     ...    ...      ...     ...
# 12028      1.0         Yes       1.0       1  Oshodi  Lagos       No     8.0
# 12029      5.0          No       6.0       6   Ikoyi  Lagos      Yes     0.0
# 12030      4.0          No       5.0       5   Ikoyi  Lagos       No     0.0
# 12031      2.0          No       2.0       3   Lekki  Lagos       No     0.0
# 12032      2.0          No       2.0       3   Lekki  Lagos       No     0.0
#
#       Stable Electricity                title               price
# 0                     No      Detached Duplex   ₦250,000,000/year
# 1                     No       Flat Apartment    ₦40,000,000/year
# 2                     No       Flat Apartment    ₦20,000,000/year
# 3                     No       Flat Apartment    ₦20,000,000/year
# 4                     No       Flat Apartment    ₦20,000,000/year
# ...                  ...                  ...                 ...
# 12028                 No  Mini flat Apartment       ₦800,000/year
# 12029                 No      Terraced Duplex    ₦20,000,000/year
# 12030                 No      Terraced Duplex    ₦40,000,000/year
# 12031                 No      Blocks Of Flats     ₦8,500,000/year
# 12032                 No      Blocks Of Flats    ₦13,000,000/year
#
# [7633 rows x 11 columns]

# %%
mask = house_pricing_data["price"].str.contains(r"\d", na=False)
house_pricing_data = house_pricing_data[mask] 

house_pricing_data["price"] = (
    house_pricing_data["price"]
    .str.replace("₦", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.replace("/year", "", regex=False)
    .astype(float)
)

house_pricing_data
# Out:
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/2276242204.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_pricing_data["price"] = (
#        bedroom parking_lot  bathroom toilets    town  state serviced  extras  \
# 0          6.0          No       6.0       7   Ikoyi  Lagos       No     0.0
# 1          3.0          No       3.0       4   Ikoyi  Lagos       No     0.0
# 2          3.0          No       3.0       4   Ikoyi  Lagos       No     0.0
# 3          3.0          No       3.0       4   Ikoyi  Lagos       No     0.0
# 4          3.0          No       3.0       4   Ikoyi  Lagos       No     0.0
# ...        ...         ...       ...     ...     ...    ...      ...     ...
# 12028      1.0         Yes       1.0       1  Oshodi  Lagos       No     8.0
# 12029      5.0          No       6.0       6   Ikoyi  Lagos      Yes     0.0
# 12030      4.0          No       5.0       5   Ikoyi  Lagos       No     0.0
# 12031      2.0          No       2.0       3   Lekki  Lagos       No     0.0
# 12032      2.0          No       2.0       3   Lekki  Lagos       No     0.0
#
#       Stable Electricity                title        price
# 0                     No      Detached Duplex  250000000.0
# 1                     No       Flat Apartment   40000000.0
# 2                     No       Flat Apartment   20000000.0
# 3                     No       Flat Apartment   20000000.0
# 4                     No       Flat Apartment   20000000.0
# ...                  ...                  ...          ...
# 12028                 No  Mini flat Apartment     800000.0
# 12029                 No      Terraced Duplex   20000000.0
# 12030                 No      Terraced Duplex   40000000.0
# 12031                 No      Blocks Of Flats    8500000.0
# 12032                 No      Blocks Of Flats   13000000.0
#
# [7552 rows x 11 columns]

# %% [markdown]
# ## Serviced, Parking_lot, Stable Electricity Column manipulation

# %%
binary_map = {'yes': 1, 'no': 0}  # Define a case-insensitive map

house_pricing_data["parking_lot"] = (
    house_pricing_data["parking_lot"]
    .str.strip() 
    .str.lower()
    .map(binary_map)  
)
# Out:
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/2301128674.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_pricing_data["parking_lot"] = (

# %%
house_pricing_data["serviced"] = (
    house_pricing_data["serviced"]
    .str.strip() 
    .str.lower()
    .map(binary_map)  
)
# Out:
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/48400886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_pricing_data["serviced"] = (

# %%
house_pricing_data["Stable Electricity"] = (
    house_pricing_data["Stable Electricity"]
    .str.strip() 
    .str.lower()
    .map(binary_map)  
)
# Out:
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/3721782764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_pricing_data["Stable Electricity"] = (

# %%
house_pricing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7552 entries, 0 to 12032
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bedroom             7552 non-null   float64
#  1   parking_lot         7552 non-null   int64
#  2   bathroom            7552 non-null   float64
#  3   toilets             7552 non-null   object
#  4   town                7552 non-null   object
#  5   state               7552 non-null   object
#  6   serviced            7552 non-null   int64
#  7   extras              7552 non-null   float64
#  8   Stable Electricity  7552 non-null   int64
#  9   title               7552 non-null   object
#  10  price               7552 non-null   float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 708.0+ KB

# %%
house_pricing_data["toilets"] = (
    house_pricing_data["toilets"]
    .astype(str)  # Ensure it's a string
    .str.extract("(\d+)")  # Extract only numeric parts
    .astype(float)  # Convert to float first to handle NaNs
    .astype("Int64")  # Convert to integer while keeping NaNs
)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/1298266244.py:4: SyntaxWarning: invalid escape sequence '\d'
#   .str.extract("(\d+)")  # Extract only numeric parts
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/1298266244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_pricing_data["toilets"] = (

# %%
house_pricing_data.dropna(subset=["toilets"], inplace=True)
# Out:
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/3995646335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_pricing_data.dropna(subset=["toilets"], inplace=True)

# %%
house_pricing_data
# Out:
#        bedroom  parking_lot  bathroom  toilets    town  state  serviced  \
# 0          6.0            0       6.0        7   Ikoyi  Lagos         0
# 1          3.0            0       3.0        4   Ikoyi  Lagos         0
# 2          3.0            0       3.0        4   Ikoyi  Lagos         0
# 3          3.0            0       3.0        4   Ikoyi  Lagos         0
# 4          3.0            0       3.0        4   Ikoyi  Lagos         0
# ...        ...          ...       ...      ...     ...    ...       ...
# 12028      1.0            1       1.0        1  Oshodi  Lagos         0
# 12029      5.0            0       6.0        6   Ikoyi  Lagos         1
# 12030      4.0            0       5.0        5   Ikoyi  Lagos         0
# 12031      2.0            0       2.0        3   Lekki  Lagos         0
# 12032      2.0            0       2.0        3   Lekki  Lagos         0
#
#        extras  Stable Electricity                title        price
# 0         0.0                   0      Detached Duplex  250000000.0
# 1         0.0                   0       Flat Apartment   40000000.0
# 2         0.0                   0       Flat Apartment   20000000.0
# 3         0.0                   0       Flat Apartment   20000000.0
# 4         0.0                   0       Flat Apartment   20000000.0
# ...       ...                 ...                  ...          ...
# 12028     8.0                   0  Mini flat Apartment     800000.0
# 12029     0.0                   0      Terraced Duplex   20000000.0
# 12030     0.0                   0      Terraced Duplex   40000000.0
# 12031     0.0                   0      Blocks Of Flats    8500000.0
# 12032     0.0                   0      Blocks Of Flats   13000000.0
#
# [7270 rows x 11 columns]

# %%
house_pricing_data = house_pricing_data[house_pricing_data["price"] < 1*1e9]

# %% [markdown]
# ## Title Manipulation

# %%
house_pricing_data["title"] = house_pricing_data["title"].str.lower()
house_pricing_data
# Out:
# /var/folders/rb/7czj_yk55kl3rj_n8m3_52sw0000gn/T/ipykernel_32294/4233986803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_pricing_data["title"] = house_pricing_data["title"].str.lower()
#        bedroom  parking_lot  bathroom  toilets    town  state  serviced  \
# 0          6.0            0       6.0        7   Ikoyi  Lagos         0
# 1          3.0            0       3.0        4   Ikoyi  Lagos         0
# 2          3.0            0       3.0        4   Ikoyi  Lagos         0
# 3          3.0            0       3.0        4   Ikoyi  Lagos         0
# 4          3.0            0       3.0        4   Ikoyi  Lagos         0
# ...        ...          ...       ...      ...     ...    ...       ...
# 12028      1.0            1       1.0        1  Oshodi  Lagos         0
# 12029      5.0            0       6.0        6   Ikoyi  Lagos         1
# 12030      4.0            0       5.0        5   Ikoyi  Lagos         0
# 12031      2.0            0       2.0        3   Lekki  Lagos         0
# 12032      2.0            0       2.0        3   Lekki  Lagos         0
#
#        extras  Stable Electricity                title        price
# 0         0.0                   0      detached duplex  250000000.0
# 1         0.0                   0       flat apartment   40000000.0
# 2         0.0                   0       flat apartment   20000000.0
# 3         0.0                   0       flat apartment   20000000.0
# 4         0.0                   0       flat apartment   20000000.0
# ...       ...                 ...                  ...          ...
# 12028     8.0                   0  mini flat apartment     800000.0
# 12029     0.0                   0      terraced duplex   20000000.0
# 12030     0.0                   0      terraced duplex   40000000.0
# 12031     0.0                   0      blocks of flats    8500000.0
# 12032     0.0                   0      blocks of flats   13000000.0
#
# [7270 rows x 11 columns]

# %%
house_pricing_data.title.value_counts()
# Out:
# title
# flat apartment                               2132
# terraced duplex                              1050
# blocks of flats                               898
# semi detached duplex                          747
# detached duplex                               731
# mini flat apartment                           658
# mini flat self contain flat apartment         221
# massionette                                   154
# mini flat shared apartment flat apartment     115
# mini flat flat apartment                      104
# mini flat studio apartment flat apartment     102
# shared apartment flat apartment                84
# detached bungalow                              77
# penthouse flat apartment                       48
# mini flat blocks of flats                      32
# studio apartment flat apartment                27
# self contain flat apartment                    21
# semi detached bungalow                         11
# Name: count, dtype: int64

# %%
# Delete some title rows (less than 10 value counts)

# Step 1: Get titles that appear more than 10 times
popular_titles = house_pricing_data["title"].value_counts()
popular_titles = popular_titles[popular_titles > 10].index

# Step 2: Filter rows where title is in the popular_titles list
house_pricing_data = house_pricing_data[house_pricing_data["title"].isin(popular_titles)]

# %%
house_pricing_data = house_pricing_data[house_pricing_data["title"] != "commercial property"]

# %%
h

# %%
house_pricing_data.to_csv('../house_data_done.csv')
